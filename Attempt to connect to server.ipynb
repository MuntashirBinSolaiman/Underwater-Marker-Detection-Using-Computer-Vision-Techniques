# %%
import cv2
import matplotlib.pyplot as plt

# Load an image
image_path = '/data/shared/CSIT_Placement_2025_3D_Reef/CBHE_BA2D_P1/images_2/frame_00001.JPG'
image = cv2.imread(image_path)
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# Display the image
plt.imshow(image)
plt.axis('off')
plt.show()
